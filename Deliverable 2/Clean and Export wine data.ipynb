# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import plotly.express as px
import os

# %%
#read in wine csv
wine_df=pd.read_csv("../Resources/Winedata.csv")
wine_df.head()
# Out:
#    id   country                                        description  \
# 0   0     Italy  Aromas include tropical fruit, broom, brimston...
# 1   1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2   2        US  Tart and snappy, the flavors of lime flesh and...
# 3   3        US  Pineapple rind, lemon pith and orange blossom ...
# 4   4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                       VulkÃ  Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2  \
# 0                 Etna                NaN
# 1                  NaN                NaN
# 2    Willamette Valley  Willamette Valley
# 3  Lake Michigan Shore                NaN
# 4    Willamette Valley  Willamette Valley
#
#                                                title         variety  \
# 0                 Nicosia 2013 VulkÃ  Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos
# 2            Rainstorm
# 3           St. Julian
# 4         Sweet Cheeks

# %%
#extract year column from title field, pop title
wine_df['Year']=wine_df['title'].str.extract(r'([1-2]\d{3})')
wine_df.pop('title')
wine_df.head()
# Out:
#    id   country                                        description  \
# 0   0     Italy  Aromas include tropical fruit, broom, brimston...
# 1   1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2   2        US  Tart and snappy, the flavors of lime flesh and...
# 3   3        US  Pineapple rind, lemon pith and orange blossom ...
# 4   4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                       VulkÃ  Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         variety  \
# 0                 Etna                NaN     White Blend
# 1                  NaN                NaN  Portuguese Red
# 2    Willamette Valley  Willamette Valley      Pinot Gris
# 3  Lake Michigan Shore                NaN        Riesling
# 4    Willamette Valley  Willamette Valley      Pinot Noir
#
#                 winery  Year
# 0              Nicosia  2013
# 1  Quinta dos Avidagos  2011
# 2            Rainstorm  2013
# 3           St. Julian  2013
# 4         Sweet Cheeks  2012

# %%
#filter wine_df for regions we want to examine
regions=['California','Washington','Bordeaux','Tuscany','Oregon','Burgundy','Cantabria','Piedmont','Veneto','New York','Alsace','Sicily & Sardinia','Champagne']
wine_df_regions=wine_df[wine_df['province'].isin(regions)]
wine_df_regions
# Out:
#             id country                                        description  \
# 0            0   Italy  Aromas include tropical fruit, broom, brimston...
# 2            2      US  Tart and snappy, the flavors of lime flesh and...
# 4            4      US  Much like the regular bottling from 2012, this...
# 6            6   Italy  Here''s a bright, informal red that opens with...
# 7            7  France  This dry and restrained wine offers spice in p...
# ...        ...     ...                                                ...
# 129964  129965  France  While it''s rich, this beautiful dry wine also...
# 129966  129967      US  Citation is given as much as a decade of bottl...
# 129967  129968  France  Well-drained gravel soil gives this wine its c...
# 129968  129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129969  129970  France  Big, rich and off-dry, this is powered by inte...
#
#                                designation  points  price           province  \
# 0                            VulkÃ  Bianco      87    NaN  Sicily & Sardinia
# 2                                      NaN      87   14.0             Oregon
# 4       Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 6                                  Belsito      87   16.0  Sicily & Sardinia
# 7                                      NaN      87   24.0             Alsace
# ...                                    ...     ...    ...                ...
# 129964        Seppi Landmann VallÃ©e Noble      90   28.0             Alsace
# 129966                                 NaN      90   75.0             Oregon
# 129967                               Kritt      90   30.0             Alsace
# 129968                                 NaN      90   32.0             Alsace
# 129969      Lieu-dit Harth CuvÃ©e Caroline      90   21.0             Alsace
#
#                  region_1           region_2          variety  \
# 0                    Etna                NaN      White Blend
# 2       Willamette Valley  Willamette Valley       Pinot Gris
# 4       Willamette Valley  Willamette Valley       Pinot Noir
# 6                Vittoria                NaN         Frappato
# 7                  Alsace                NaN  GewÃ¼rztraminer
# ...                   ...                ...              ...
# 129964             Alsace                NaN       Pinot Gris
# 129966             Oregon       Oregon Other       Pinot Noir
# 129967             Alsace                NaN  GewÃ¼rztraminer
# 129968             Alsace                NaN       Pinot Gris
# 129969             Alsace                NaN  GewÃ¼rztraminer
#
#                           winery  Year
# 0                        Nicosia  2013
# 2                      Rainstorm  2013
# 4                   Sweet Cheeks  2012
# 6                Terre di Giurfo  2013
# 7                       Trimbach  2012
# ...                          ...   ...
# 129964  Domaine RieflÃ©-Landmann  2013
# 129966                  Citation  2004
# 129967           Domaine Gresser  2013
# 129968      Domaine Marcel Deiss  2012
# 129969          Domaine Schoffit  2012
#
# [81059 rows x 12 columns]

# %%
# drop records with no year
wine_df_regions.dropna(subset=['Year'],inplace=True)
wine_df_regions
# Out:
# /Users/kyle/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             id country                                        description  \
# 0            0   Italy  Aromas include tropical fruit, broom, brimston...
# 2            2      US  Tart and snappy, the flavors of lime flesh and...
# 4            4      US  Much like the regular bottling from 2012, this...
# 6            6   Italy  Here''s a bright, informal red that opens with...
# 7            7  France  This dry and restrained wine offers spice in p...
# ...        ...     ...                                                ...
# 129964  129965  France  While it''s rich, this beautiful dry wine also...
# 129966  129967      US  Citation is given as much as a decade of bottl...
# 129967  129968  France  Well-drained gravel soil gives this wine its c...
# 129968  129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129969  129970  France  Big, rich and off-dry, this is powered by inte...
#
#                                designation  points  price           province  \
# 0                            VulkÃ  Bianco      87    NaN  Sicily & Sardinia
# 2                                      NaN      87   14.0             Oregon
# 4       Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 6                                  Belsito      87   16.0  Sicily & Sardinia
# 7                                      NaN      87   24.0             Alsace
# ...                                    ...     ...    ...                ...
# 129964        Seppi Landmann VallÃ©e Noble      90   28.0             Alsace
# 129966                                 NaN      90   75.0             Oregon
# 129967                               Kritt      90   30.0             Alsace
# 129968                                 NaN      90   32.0             Alsace
# 129969      Lieu-dit Harth CuvÃ©e Caroline      90   21.0             Alsace
#
#                  region_1           region_2          variety  \
# 0                    Etna                NaN      White Blend
# 2       Willamette Valley  Willamette Valley       Pinot Gris
# 4       Willamette Valley  Willamette Valley       Pinot Noir
# 6                Vittoria                NaN         Frappato
# 7                  Alsace                NaN  GewÃ¼rztraminer
# ...                   ...                ...              ...
# 129964             Alsace                NaN       Pinot Gris
# 129966             Oregon       Oregon Other       Pinot Noir
# 129967             Alsace                NaN  GewÃ¼rztraminer
# 129968             Alsace                NaN       Pinot Gris
# 129969             Alsace                NaN  GewÃ¼rztraminer
#
#                           winery  Year
# 0                        Nicosia  2013
# 2                      Rainstorm  2013
# 4                   Sweet Cheeks  2012
# 6                Terre di Giurfo  2013
# 7                       Trimbach  2012
# ...                          ...   ...
# 129964  Domaine RieflÃ©-Landmann  2013
# 129966                  Citation  2004
# 129967           Domaine Gresser  2013
# 129968      Domaine Marcel Deiss  2012
# 129969          Domaine Schoffit  2012
#
# [78164 rows x 12 columns]

# %%
#drop records from before 1990
wine_df_regions=wine_df_regions[wine_df_regions['Year']>'1990']
wine_df_regions
# Out:
#             id country                                        description  \
# 0            0   Italy  Aromas include tropical fruit, broom, brimston...
# 2            2      US  Tart and snappy, the flavors of lime flesh and...
# 4            4      US  Much like the regular bottling from 2012, this...
# 6            6   Italy  Here''s a bright, informal red that opens with...
# 7            7  France  This dry and restrained wine offers spice in p...
# ...        ...     ...                                                ...
# 129964  129965  France  While it''s rich, this beautiful dry wine also...
# 129966  129967      US  Citation is given as much as a decade of bottl...
# 129967  129968  France  Well-drained gravel soil gives this wine its c...
# 129968  129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129969  129970  France  Big, rich and off-dry, this is powered by inte...
#
#                                designation  points  price           province  \
# 0                            VulkÃ  Bianco      87    NaN  Sicily & Sardinia
# 2                                      NaN      87   14.0             Oregon
# 4       Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 6                                  Belsito      87   16.0  Sicily & Sardinia
# 7                                      NaN      87   24.0             Alsace
# ...                                    ...     ...    ...                ...
# 129964        Seppi Landmann VallÃ©e Noble      90   28.0             Alsace
# 129966                                 NaN      90   75.0             Oregon
# 129967                               Kritt      90   30.0             Alsace
# 129968                                 NaN      90   32.0             Alsace
# 129969      Lieu-dit Harth CuvÃ©e Caroline      90   21.0             Alsace
#
#                  region_1           region_2          variety  \
# 0                    Etna                NaN      White Blend
# 2       Willamette Valley  Willamette Valley       Pinot Gris
# 4       Willamette Valley  Willamette Valley       Pinot Noir
# 6                Vittoria                NaN         Frappato
# 7                  Alsace                NaN  GewÃ¼rztraminer
# ...                   ...                ...              ...
# 129964             Alsace                NaN       Pinot Gris
# 129966             Oregon       Oregon Other       Pinot Noir
# 129967             Alsace                NaN  GewÃ¼rztraminer
# 129968             Alsace                NaN       Pinot Gris
# 129969             Alsace                NaN  GewÃ¼rztraminer
#
#                           winery  Year
# 0                        Nicosia  2013
# 2                      Rainstorm  2013
# 4                   Sweet Cheeks  2012
# 6                Terre di Giurfo  2013
# 7                       Trimbach  2012
# ...                          ...   ...
# 129964  Domaine RieflÃ©-Landmann  2013
# 129966                  Citation  2004
# 129967           Domaine Gresser  2013
# 129968      Domaine Marcel Deiss  2012
# 129969          Domaine Schoffit  2012
#
# [78037 rows x 12 columns]

# %%
#replace wine region values with matching regions from weather data

wine_df_regions.loc[wine_df_regions['province']=='Piedmont','province']="Piemonte"
wine_df_regions.loc[wine_df_regions['province']=='Sicily & Sardinia','province']="Sicilia"
wine_df_regions.loc[wine_df_regions['province']=='Bordeaux','province']="Aquitaine"
wine_df_regions.loc[wine_df_regions['province']=='Northern Spain','province']="Cantabria"
wine_df_regions.loc[wine_df_regions['province']=='Champagne','province']="Champagne-Ardenne"

wine_df_regions
# Out:
# /Users/kyle/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             id country                                        description  \
# 0            0   Italy  Aromas include tropical fruit, broom, brimston...
# 2            2      US  Tart and snappy, the flavors of lime flesh and...
# 4            4      US  Much like the regular bottling from 2012, this...
# 6            6   Italy  Here''s a bright, informal red that opens with...
# 7            7  France  This dry and restrained wine offers spice in p...
# ...        ...     ...                                                ...
# 129964  129965  France  While it''s rich, this beautiful dry wine also...
# 129966  129967      US  Citation is given as much as a decade of bottl...
# 129967  129968  France  Well-drained gravel soil gives this wine its c...
# 129968  129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129969  129970  France  Big, rich and off-dry, this is powered by inte...
#
#                                designation  points  price province  \
# 0                            VulkÃ  Bianco      87    NaN  Sicilia
# 2                                      NaN      87   14.0   Oregon
# 4       Vintner's Reserve Wild Child Block      87   65.0   Oregon
# 6                                  Belsito      87   16.0  Sicilia
# 7                                      NaN      87   24.0   Alsace
# ...                                    ...     ...    ...      ...
# 129964        Seppi Landmann VallÃ©e Noble      90   28.0   Alsace
# 129966                                 NaN      90   75.0   Oregon
# 129967                               Kritt      90   30.0   Alsace
# 129968                                 NaN      90   32.0   Alsace
# 129969      Lieu-dit Harth CuvÃ©e Caroline      90   21.0   Alsace
#
#                  region_1           region_2          variety  \
# 0                    Etna                NaN      White Blend
# 2       Willamette Valley  Willamette Valley       Pinot Gris
# 4       Willamette Valley  Willamette Valley       Pinot Noir
# 6                Vittoria                NaN         Frappato
# 7                  Alsace                NaN  GewÃ¼rztraminer
# ...                   ...                ...              ...
# 129964             Alsace                NaN       Pinot Gris
# 129966             Oregon       Oregon Other       Pinot Noir
# 129967             Alsace                NaN  GewÃ¼rztraminer
# 129968             Alsace                NaN       Pinot Gris
# 129969             Alsace                NaN  GewÃ¼rztraminer
#
#                           winery  Year
# 0                        Nicosia  2013
# 2                      Rainstorm  2013
# 4                   Sweet Cheeks  2012
# 6                Terre di Giurfo  2013
# 7                       Trimbach  2012
# ...                          ...   ...
# 129964  Domaine RieflÃ©-Landmann  2013
# 129966                  Citation  2004
# 129967           Domaine Gresser  2013
# 129968      Domaine Marcel Deiss  2012
# 129969          Domaine Schoffit  2012
#
# [78037 rows x 12 columns]

# %%
#drop unneeded fields
wine_df_regions=wine_df_regions.drop(['id','description','designation','region_1','region_2','country'],axis=1)

# %%
#drop wines without a price
wine_df_regions=wine_df_regions.dropna(subset=['price'])

# %%
#keep only wines with a price less than $100
wine_df_regions=wine_df_regions[wine_df_regions['price']<101]

# %%
wine_df_regions
# Out:
#         points  price province          variety                    winery  \
# 2           87   14.0   Oregon       Pinot Gris                 Rainstorm
# 4           87   65.0   Oregon       Pinot Noir              Sweet Cheeks
# 6           87   16.0  Sicilia         Frappato           Terre di Giurfo
# 7           87   24.0   Alsace  GewÃ¼rztraminer                  Trimbach
# 9           87   27.0   Alsace       Pinot Gris        Jean-Baptiste Adam
# ...        ...    ...      ...              ...                       ...
# 129964      90   28.0   Alsace       Pinot Gris  Domaine RieflÃ©-Landmann
# 129966      90   75.0   Oregon       Pinot Noir                  Citation
# 129967      90   30.0   Alsace  GewÃ¼rztraminer           Domaine Gresser
# 129968      90   32.0   Alsace       Pinot Gris      Domaine Marcel Deiss
# 129969      90   21.0   Alsace  GewÃ¼rztraminer          Domaine Schoffit
#
#         Year
# 2       2013
# 4       2012
# 6       2013
# 7       2012
# 9       2012
# ...      ...
# 129964  2013
# 129966  2004
# 129967  2013
# 129968  2012
# 129969  2012
#
# [70214 rows x 6 columns]

# %%
#count varieties and create list of those with less than 150 entries
variety_counts=wine_df_regions.variety.value_counts()
replace_varieties=list(variety_counts[variety_counts<150].index)
replace_varieties
# Out:
# ['G-S-M',
#  'Roussanne',
#  'AlbariÃ±o',
#  'Vernaccia',
#  'Grenache Blanc',
#  'Chenin Blanc',
#  'Grillo',
#  'Primitivo',
#  'GrÃ¼ner Veltliner',
#  'SÃ©millon',
#  'Nerello Mascalese',
#  'Arneis',
#  'FumÃ© Blanc',
#  'Cortese',
#  'Muscat',
#  'Cabernet Sauvignon-Syrah',
#  'Alsace white blend',
#  'Shiraz',
#  'Port',
#  'CarmenÃ¨re',
#  'Rosato',
#  'Tannat',
#  'Marsanne',
#  'Semillon-Sauvignon Blanc',
#  'Sauvignon Blanc-Semillon',
#  'Cabernet Sauvignon-Merlot',
#  'Prosecco',
#  'Carricante',
#  'Syrah-Grenache',
#  'Muscat Canelli',
#  'Frappato',
#  'Sylvaner',
#  'Pinot Nero',
#  'Cinsault',
#  'Prugnolo Gentile',
#  'Lemberger',
#  'Pinot Meunier',
#  'Carignane',
#  'AligotÃ©',
#  'Cannonau',
#  'Syrah-Cabernet Sauvignon',
#  'Zibibbo',
#  'Inzolia',
#  'Claret',
#  'Insolia',
#  'Charbono',
#  'Grenache-Syrah',
#  'Catarratto',
#  'Verdelho',
#  'Cabernet Blend',
#  'Petite Verdot',
#  'Vidal Blanc',
#  'Gamay Noir',
#  'Merlot-Cabernet Franc',
#  'Marsanne-Roussanne',
#  'Touriga Nacional',
#  'Merlot-Cabernet Sauvignon',
#  'Syrah-Petite Sirah',
#  'Baco Noir',
#  'Teroldego',
#  'Orange Muscat',
#  'Corvina',
#  'BlaufrÃ¤nkisch',
#  'Tocai Friulano',
#  'Auxerrois',
#  'Fiano',
#  'Aglianico',
#  'Gamay',
#  'Montepulciano',
#  'Carignano',
#  'MÃ¼ller-Thurgau',
#  'Cabernet Franc-Merlot',
#  'Garnacha',
#  'Graciano',
#  'Malvasia Bianca',
#  'Roussanne-Viognier',
#  'RuchÃ©',
#  'Colombard',
#  'Raboso',
#  'Counoise',
#  'White Riesling',
#  'Chenin Blanc-Viognier',
#  'Muscat Blanc',
#  'Cabernet Sauvignon-Cabernet Franc',
#  'Sauvignon',
#  'Black Muscat',
#  'Pinot Auxerrois',
#  'Pinot Noir-Gamay',
#  'Brachetto',
#  'Carignan',
#  'Picpoul',
#  'Trebbiano',
#  'Lagrein',
#  'Viognier-Roussanne',
#  'Seyval Blanc',
#  'Syrah-Viognier',
#  'Syrah-MourvÃ¨dre',
#  'Johannisberg Riesling',
#  'Grecanico',
#  'Pinotage',
#  'Monastrell',
#  'Zweigelt',
#  'Merlot-Cabernet',
#  'Perricone',
#  'Cabernet-Syrah',
#  'Syrah-Tempranillo',
#  'Rkatsiteli',
#  'Refosco',
#  'Durella',
#  'Chardonnay-Viognier',
#  'ValdiguiÃ©',
#  'Syrah-Cabernet',
#  'Malbec-Merlot',
#  'Nerello Cappuccio',
#  'Alicante',
#  'Mission',
#  'Alicante Bouschet',
#  'Cabernet Merlot',
#  'Grenache-Carignan',
#  'Muskat Ottonel',
#  'Timorasso',
#  'Grenache-MourvÃ¨dre',
#  'Cabernet Sauvignon-Sangiovese',
#  'Sangiovese-Syrah',
#  'Pinot-Chardonnay',
#  'TorrontÃ©s',
#  'Traminette',
#  'Sangiovese-Cabernet Sauvignon',
#  'Monica',
#  'Manzoni',
#  'Edelzwicker',
#  'Grenache Blend',
#  'Symphony',
#  'Saperavi',
#  'Sangiovese Cabernet',
#  'Tempranillo Blend',
#  'Dornfelder',
#  'Bovale',
#  'Syrah-Cabernet Franc',
#  'Semillon-Chardonnay',
#  'Malvasia Nera',
#  'Aleatico',
#  'Vignoles',
#  'Nascetta',
#  'Sagrantino',
#  'Trousseau Gris',
#  'Chardonnay-Semillon',
#  'GewÃ¼rztraminer-Riesling',
#  'Moscadello',
#  'Mondeuse',
#  'Ciliegiolo',
#  'Verdejo',
#  'Chasselas',
#  'Mataro',
#  'Pugnitello',
#  'Cabernet Sauvignon-Malbec',
#  'Canaiolo',
#  'Ugni Blanc',
#  'Nuragus',
#  'Souzao',
#  'Malvasia',
#  'Viognier-Grenache Blanc',
#  'Negrette',
#  'Viognier-Chardonnay',
#  'Pinot Noir-Syrah',
#  'Freisa',
#  'Scheurebe',
#  'Madeleine Angevine',
#  'Cabernet Sauvignon-Shiraz',
#  'Malbec-Tannat',
#  'Vidal',
#  'Vespolina',
#  'Sauvignon Gris',
#  'MourvÃ¨dre-Syrah',
#  'Viognier-Marsanne',
#  'Nasco',
#  'Tempranillo-Cabernet Sauvignon',
#  'Marquette',
#  'Marsanne-Viognier',
#  'Albarossa',
#  'Cabernet Pfeffer',
#  'Friulano',
#  'Muscadine',
#  'Cabernet',
#  'Ribolla Gialla',
#  'Erbaluce',
#  'Carignan-Grenache',
#  'Uvalino',
#  'Muscat Hamburg',
#  'Chelois',
#  'Chardonnay-AlbariÃ±o',
#  'Morio Muskat',
#  'Roussanne-Marsanne',
#  'Torbato',
#  'Viognier-GewÃ¼rztraminer',
#  'Moscato Giallo',
#  'Cabernet Franc-Lemberger',
#  'Pinot Bianco',
#  'Tempranillo-Garnacha',
#  'Ansonica',
#  'Grenache Noir',
#  'Cayuga',
#  'Falanghina',
#  'Pinot Blanc-Pinot Noir',
#  'Muskat',
#  'Vespaiolo',
#  'Vermentino Nero',
#  'Merlot-Malbec',
#  'Chardonnay-Pinot Gris',
#  'Abouriou',
#  'Pinot Blanc-Viognier',
#  'Chardonnay-Riesling',
#  'Grignolino',
#  'Syrah-Grenache-Viognier',
#  'Silvaner',
#  'Petit Manseng',
#  'Rosado',
#  'Tannat-Syrah',
#  'Pinot Blanc-Chardonnay',
#  'Malbec-Cabernet Sauvignon',
#  'Sacy',
#  'Greco',
#  'Malbec-Syrah',
#  'Chardonnay-Pinot Blanc',
#  'AlvarelhÃ£o',
#  'Riesling-Chardonnay',
#  'Verdicchio',
#  'Tokay Pinot Gris',
#  'Cabernet Sauvignon-CarmenÃ¨re',
#  'Cabernet-Shiraz',
#  'Viognier-ValdiguiÃ©',
#  'Melon',
#  'Muscadelle',
#  'Tempranillo-Syrah',
#  'Tinta Madeira',
#  'Favorita',
#  'Colombard-Ugni Blanc',
#  'Clairette',
#  'Valvin Muscat',
#  'Cabernet Sauvignon-Barbera',
#  'Tocai',
#  "Muscat d'Alexandrie",
#  'Syrah-Merlot',
#  'Alvarinho',
#  'Sauvignon MusquÃ©',
#  'Roussanne-Grenache Blanc',
#  'Albanello',
#  'Touriga Nacional Blend',
#  'Diamond',
#  'Barbera-Nebbiolo',
#  'Franconia',
#  'Syrah-Petit Verdot',
#  'Sauvignon-SÃ©millon',
#  'Cabernet Sauvignon-Tempranillo',
#  'Tinta Amarela',
#  'Pinot Gris-GewÃ¼rztraminer',
#  'Muscat Blanc Ã\xa0 Petits Grains',
#  'Garnacha Blanca',
#  'Chancellor',
#  'Colorino',
#  'Kerner',
#  'Siegerrebe',
#  'Moscato di Noto',
#  'Negroamaro',
#  'Cabernet Franc-Cabernet Sauvignon',
#  'Chambourcin',
#  'Pinot Grigio-Sauvignon Blanc']

# %%
#replace variety with NaN
wine_df_regions['variety'].replace(to_replace=replace_varieties,value="NaN",inplace=True)
wine_df_regions
# Out:
#         points  price province          variety                    winery  \
# 2           87   14.0   Oregon       Pinot Gris                 Rainstorm
# 4           87   65.0   Oregon       Pinot Noir              Sweet Cheeks
# 6           87   16.0  Sicilia              NaN           Terre di Giurfo
# 7           87   24.0   Alsace  GewÃ¼rztraminer                  Trimbach
# 9           87   27.0   Alsace       Pinot Gris        Jean-Baptiste Adam
# ...        ...    ...      ...              ...                       ...
# 129964      90   28.0   Alsace       Pinot Gris  Domaine RieflÃ©-Landmann
# 129966      90   75.0   Oregon       Pinot Noir                  Citation
# 129967      90   30.0   Alsace  GewÃ¼rztraminer           Domaine Gresser
# 129968      90   32.0   Alsace       Pinot Gris      Domaine Marcel Deiss
# 129969      90   21.0   Alsace  GewÃ¼rztraminer          Domaine Schoffit
#
#         Year
# 2       2013
# 4       2012
# 6       2013
# 7       2012
# 9       2012
# ...      ...
# 129964  2013
# 129966  2004
# 129967  2013
# 129968  2012
# 129969  2012
#
# [70214 rows x 6 columns]

# %%
#Drop Na varieties
wine_df_regions=wine_df_regions[wine_df_regions['variety']!='NaN']
wine_df_regions
# Out:
#         points  price    province             variety  \
# 2           87   14.0      Oregon          Pinot Gris
# 4           87   65.0      Oregon          Pinot Noir
# 7           87   24.0      Alsace     GewÃ¼rztraminer
# 9           87   27.0      Alsace          Pinot Gris
# 10          87   19.0  California  Cabernet Sauvignon
# ...        ...    ...         ...                 ...
# 129964      90   28.0      Alsace          Pinot Gris
# 129966      90   75.0      Oregon          Pinot Noir
# 129967      90   30.0      Alsace     GewÃ¼rztraminer
# 129968      90   32.0      Alsace          Pinot Gris
# 129969      90   21.0      Alsace     GewÃ¼rztraminer
#
#                           winery  Year
# 2                      Rainstorm  2013
# 4                   Sweet Cheeks  2012
# 7                       Trimbach  2012
# 9             Jean-Baptiste Adam  2012
# 10            Kirkland Signature  2011
# ...                          ...   ...
# 129964  Domaine RieflÃ©-Landmann  2013
# 129966                  Citation  2004
# 129967           Domaine Gresser  2013
# 129968      Domaine Marcel Deiss  2012
# 129969          Domaine Schoffit  2012
#
# [66481 rows x 6 columns]

# %%
#get winery value counts
winery_vcs=wine_df_regions['winery'].value_counts()
winery_vcs
# Out:
# Testarossa                    217
# Williams Selyem               198
# Chateau Ste. Michelle         191
# Columbia Crest                146
# Kendall-Jackson               127
#                              ...
# ChÃ¢teau Mirefleurs             1
# Luko                            1
# ChÃ¢teau Haut-Sorillon          1
# ChÃ¢teau la Tour de Bessan      1
# ChÃ¢teau Haut-Francarney        1
# Name: winery, Length: 8506, dtype: int64

# %%
# count number of wineries with less than 4 records
winery_counts=wine_df_regions.winery.value_counts()
replace_wineries=list(winery_counts[winery_counts<4].index)
len(replace_wineries)
# Out:
# 4438

# %%
#filer df and keep only records where winery has 4 or more records
wine_df_regions=wine_df_regions.groupby('winery').filter(lambda x: len(x)>3)

# %%
#export cleaned data
#wine_df_regions.to_csv('../Resources/wine_data_cleaned.csv',index=False)

# %%
#create provinces list
provinces=wine_df_regions['province'].unique()
provinces
# Out:
# array(['Oregon', 'Alsace', 'California', 'Sicilia', 'Aquitaine',
#        'Washington', 'Burgundy', 'New York', 'Tuscany', 'Piemonte',
#        'Veneto', 'Champagne-Ardenne'], dtype=object)

# %%
#write price v point image for each region
for p in provinces:
    fig=px.scatter(wine_df_regions[wine_df_regions['province']=='California'],x='price',y='points',title= 'Price vs Points by Region - '+p, trendline='ols').write_image("../Images/"+p+".png", engine="kaleido")

# %%
a=wine_df_regions['points'].groupby(wine_df_regions['province']).mean()
a

# %% [markdown]
# ### Target
# - points
#
# ### Variables
# - province - categorical
# - region_1 - categorical
# - variety - categorical
# - winery - categorical
# - Year - categorical
#
# ### Maybe Not Variables
# - description
# - designation
# - price
#
# ### Definitely Not Variables
# - id
# - country
# - region_2
